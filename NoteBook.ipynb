# %%
# %matplotlib
import logging
from importlib import reload
import pylab as pl
import numpy as np
from utils import scatter
# Out:
# Using matplotlib backend: Qt5Agg
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %%
from pickle import load, dump
import os
import bz2

def parseMails():
    from tokenizer import iterTokenizedSentences
    from emailparser import mailLoaderGen
    
    mails = []
    for mail in mailLoaderGen():
        mails.append(mail)
        mail.sents = list(iterTokenizedSentences(mail.description))
    return mails

dbfile = "tokmail.pk.bz2"
if os.path.exists(dbfile):
    with bz2.open(dbfile, "rb") as f:
        mails = load(f)
else:        
    mails = parseMails()
    with bz2.open(dbfile, "wb") as f:
        dump(mails, f)

# %%
from Stemmer import Stemmer
from collections import Counter

# Premier compatage du vocabulaire
vocabCount = Counter(w for mail in mails 
                       for sent in mail.sents
                       for w in sent)

# Création du stemmer avec ce vocabulaire
stem = Stemmer({w for w,count in vocabCount.items() if count >= 3})

# Applique le stemmer sur l'ensemble des phrases:
for mail in mails:
    mail.words = [w for s in mail.sents for w in s]
    mail.stemSents = [[stem.stem(w) for w in s] for s in mail.sents]
    mail.stemWords = [w for s in mail.stemSents for w in s]
    
# Second comptage du compatage du vocabulaire
vocabCount = Counter(w for mail in mails for w in mail.words)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import TruncatedSVD,PCA
from sklearn.manifold import TSNE
from sklearn.pipeline import make_pipeline
from sklearn.cluster import KMeans, AffinityPropagation, DBSCAN

tf = TfidfVectorizer(analyzer=lambda mail: mail.stemWords, min_df=3, max_df=0.7)
svd = TruncatedSVD(n_components=500)
lsa = make_pipeline(tf, svd)

X = lsa.fit_transform(mails)

Y = TSNE().fit_transform(X)

# %%
km = KMeans(n_clusters=20, init='k-means++', max_iter=100, n_init=20)
km.fit(X)
pl.scatter(Y.T[0], Y.T[1], c =km.labels_);

# %%
mailLogLength = np.log([len(mail.words) for mail in mails])
sujets = [mail.sujet for mail in mails]
scatter(Y, sujets, km.labels_, 0.1*mailLogLength)
# Out:
#     <div class="plotdiv" id="425d1e16-d271-4172-b667-85c0d80f3fdd"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("425d1e16-d271-4172-b667-85c0d80f3fdd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '425d1e16-d271-4172-b667-85c0d80f3fdd' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e7f199aa-b888-4c0a-b893-9cf647c35c68": {"title": "Bokeh Application", "roots": {"root_ids": ["1eb164ac-4f03-47af-8a8c-2f7f1d33a5cd"], "references": [{"id": "b7ce47a6-7af1-4f50-9846-8367687690ef", "attributes": {"fill_alpha": {"value": 0.1}, "radius": {"units": "data", "field": "radius"}, "line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}}, "type": "Circle"}, {"id": "a3a4bacc-f1b7-4f38-a04d-dc363effe4f2", "attributes": {"selection_glyph": null, "nonselection_glyph": {"id": "b7ce47a6-7af1-4f50-9846-8367687690ef", "type": "Circle"}, "hover_glyph": null, "data_source": {"id": "9e60ee89-3de6-48aa-9558-cbab55cd32e8", "type": "ColumnDataSource"}, "glyph": {"id": "502bedd5-eeca-40d7-acd7-8c034266407a", "type": "Circle"}}, "type": "GlyphRenderer"}, {"id": "38de91a0-7bdc-4733-a37e-a085aa28a502", "attributes": {"plot": {"id": "1eb164ac-4f03-47af-8a8c-2f7f1d33a5cd", "type": "Plot", "subtype": "Figure"}}, "type": "WheelZoomTool"}, {"id": "b49f2cad-fadd-4543-9c57-505e0f490ee9", "attributes": {}, "type": "ToolEvents"}, {"id": "9e60ee89-3de6-48aa-9558-cbab55cd32e8", "attributes": {"data": {"color": ["#ffffbf", "#ffffbf", "#5e4fa2", "#66c2a5", "#ffffbf", "#ffffbf", "#66c2a5", "#d53e4f", "#ffffbf", "#ffffbf", "#5e4fa2", "#5e4fa2", "#3288bd", "#5e4fa2", "#5e4fa2", "#ffffbf", "#f46d43", "#5e4fa2", "#5e4fa2", "#f46d43", "#ffffbf", "#5e4fa2", "#66c2a5", "#66c2a5", "#5e4fa2", "#66c2a5", "#66c2a5", "#ffffbf", "#ffffbf", "#66c2a5", "#d53e4f", "#5e4fa2", "#f46d43", "#ffffbf", "#66c2a5", "#ffffbf", "#ffffbf", "#66c2a5", "#3288bd", "#d53e4f", "#5e4fa2", "#5e4fa2", "#ffffbf", "#ffffbf", "#ffffbf", "#ffffbf", "#d53e4f", "#5e4fa2", "#3288bd", "#e6f598", "#ffffbf", "#e6f598", "#66c2a5", "#ffffbf", "#e6f598", "#d53e4f", "#ffffbf", "#d53e4f", "#ffffbf", "#66c2a5", "#66c2a5", "#9e0142", "#5e4fa2", "#ffffbf", "#3288bd", "#3288bd", "#5e4fa2", "#3288bd", "#ffffbf", "#66c2a5", "#f46d43", "#5e4fa2", "#5e4fa2", "#ffffbf", "#3288bd", "#ffffbf", "#ffffbf", "#ffffbf", "#5e4fa2", "#66c2a5", "#f46d43", "#ffffbf", "#66c2a5", "#ffffbf", "#d53e4f", "#ffffbf", "#ffffbf", "#ffffbf", "#66c2a5", "#d53e4f", "#f46d43", "#ffffbf", "#ffffbf", "#ffffbf", "#ffffbf", "#fdae61", "#5e4fa2", "#5e4fa2", "#5e4fa2", "#ffffbf", "#3288bd", "#ffffbf", "#ffffbf", "#3288bd", "#66c2a5", "#ffffbf", "#ffffbf", "#f46d43", "#5e4fa2", "#ffffbf", "#f46d43", "#5e4fa2", "#66c2a5", "#3288bd", "#ffffbf", "#e6f598", "#3288bd", "#3288bd", "#5e4fa2", "#5e4fa2", "#ffffbf", "#5e4fa2", "#ffffbf", "#f46d43", "#ffffbf", "#ffffbf", "#ffffbf", "#ffffbf", "#ffffbf", "#ffffbf", "#5e4fa2", "#ffffbf", "#5e4fa2", "#5e4fa2", "#3288bd", "#5e4fa2", "#ffffbf", "#f46d43", "#f46d43", "#5e4fa2", "#3288bd", "#e6f598", "#66c2a5", "#ffffbf", "#66c2a5", "#ffffbf", "#ffffbf", "#66c2a5", "#ffffbf", "#e6f598", "#ffffbf", "#d53e4f", "#66c2a5", "#d53e4f", "#f46d43", "#ffffbf", "#ffffbf", "#5e4fa2", "#f46d43", "#f46d43", "#ffffbf", "#ffffbf", "#66c2a5", "#5e4fa2", "#66c2a5", "#5e4fa2", "#5e4fa2", "#d53e4f", "#ffffbf", "#ffffbf", "#66c2a5", "#ffffbf", "#3288bd", "#66c2a5", "#66c2a5", "#ffffbf", "#ffffbf", "#5e4fa2", "#ffffbf", "#ffffbf", "#9e0142", "#ffffbf", "#ffffbf", "#5e4fa2", "#ffffbf", "#5e4fa2", "#ffffbf", "#fee08b", "#66c2a5", "#ffffbf", "#5e4fa2", "#66c2a5", "#9e0142", "#d53e4f", "#ffffbf", "#3288bd", "#5e4fa2", "#f46d43", "#fee08b", "#d53e4f", "#5e4fa2", "#ffffbf", "#ffffbf", "#d53e4f", "#ffffbf", "#f46d43", "#fee08b", "#ffffbf", "#66c2a5", "#66c2a5", "#5e4fa2", "#66c2a5", "#5e4fa2", "#66c2a5", "#5e4fa2", "#9e0142", "#ffffbf", "#ffffbf", "#ffffbf", "#5e4fa2", "#3288bd", "#ffffbf", "#ffffbf", "#fee08b", "#3288bd", "#fee08b", "#66c2a5", "#ffffbf", "#ffffbf", "#3288bd", "#5e4fa2", "#ffffbf", "#66c2a5", "#ffffbf", "#d53e4f", "#ffffbf", "#66c2a5", "#ffffbf", "#ffffbf", "#3288bd", "#5e4fa2", "#5e4fa2", "#3288bd", "#ffffbf", "#ffffbf", "#5e4fa2", "#ffffbf", "#ffffbf", "#ffffbf", "#ffffbf", "#ffffbf", "#66c2a5", "#5e4 ...

# %%
for cl in range(km.labels_.max()+1):
    ct = Counter()
    n = 0
    for i in np.where(km.labels_==cl)[0]:
        ct.update(mails[i].tags)
        n += 1
    print(cl, n, ct)
# Out:
# 0 98 Counter({'CDD': 7, 'CDD Ingénieur': 4, 'Post-doc / IR': 3, 'Emploi': 1, "CMSR@ECCB'14": 1, 'Fwd:  Formation ENVOL 2014 : Tests et Validation': 1, 'MdC': 1, 'PostDoc': 1, 'CDI': 1})
# 1 69 Counter({'CDD': 19, 'Post-doc / IR': 19, 'Thèse': 7, 'Stage': 3, 'Gtpb': 1})
# 2 120 Counter({'CDD': 56, 'CDD Ingénieur': 37, 'CDI': 24, 'CDI autre': 15, 'CDD autre': 10, 'Post-doc / IR': 8, 'Stage': 5, 'IE': 4, 'PR': 3, 'IR': 2, 'Emploi': 2})
# 3 4 Counter()
# 4 6 Counter({'CDI': 1, 'CDI autre': 1})
# 5 185 Counter({'CDD': 80, 'Post-doc / IR': 67, 'Thèse': 9, 'CDD Ingénieur': 8, 'CDD autre': 5, 'CDI autre': 5, 'CDI': 5, 'Stage': 4, 'Emploi': 2, 'Call for Participations': 1, 'CDD/Ingénieur': 1})
# 6 11 Counter({'CDI': 3, 'MdC': 3})
# 7 3 Counter()
# 8 46 Counter({'Stage': 7, 'Thèse': 6})
# 9 71 Counter({"CMSR@ECCB'14": 1, "ECCB'14": 1})
# 10 26 Counter({'CDI': 8, 'CDD': 5, 'Stage': 4, 'IR': 3, 'CDD Ingénieur': 3, 'CDI autre': 3, 'PR': 1, 'Post-doc / IR': 1, 'CDD autre': 1, 'IE': 1, 'Thèse': 1})
# 11 122 Counter({'Post-doc / IR': 12, 'CDD': 12, 'CDI': 3, "ECCB'14": 2, 'Thèse': 2, 'PR': 1, 'CDI autre': 1, 'Thèse/PhD': 1, 'Emploi': 1, 'Ngi-international-liaisons': 1, 'MdC': 1})
# 12 7 Counter()
# 13 61 Counter({'CDD': 32, 'CDD Ingénieur': 23, 'CDI': 11, 'Post-doc / IR': 9, 'CDI autre': 6, 'IE': 5, 'Stage': 4, 'Emploi': 2, 'CDI ingénieur': 1, 'CDD ingénieurdéveloppeur': 1, 'offre emploi': 1})
# 14 4 Counter({'CDD': 1, 'Post-doc / IR': 1})
# 15 19 Counter({'Gtpb': 19})
# 16 152 Counter({'Stage': 56, 'CDD': 21, 'Post-doc / IR': 12, 'CDD Ingénieur': 9, 'PR': 4, 'Emploi': 4, 'CDI': 4, 'Thèse': 3, '1 - 4 avril 2014': 1, '29 septembre-1er octobre 2014': 1, '2-3 octobre 2014': 1, '23-26 septembre 2014': 1})
# 17 7 Counter()
# 18 14 Counter({'CDI': 2, 'CDI autre': 1, 'IR': 1})
# 19 4 Counter()

# %%
 for i in np.where(km.labels_==9)[0]:
        print(i)
        print(mails[i].sujet)
# Out:
# 7
# 3rd call for peer-reviewed short papers, aSSB'15 Thematic school "Advances in Systems & Synthetic Biology"
# 30
# AlCoB 2015: 2nd call for papers
# 39
# CFP: The International Technology Management Conference (ITMC2015)
# 46
# Deadline December 19 for peer-reviewed short papers, aSSB'15 Thematic school "Advances in Systems & Synthetic Biology"
# 55
# Computational Methods in Systems Biology 2015, Nantes, September 16-18 2015
# 57
# Call for papers - MLJ Special issue on Dynamic Networks & Knowledge Discovery
# 84
# AlCoB 2015: 1st call for papers
# 89
# CFP: IJCNN 2015 Special Session on "Multiple Clusterings"
# 151
# international conference 'Perspectives in Environmental and Systems Biology' (Grenoble, France, April 13-15, 2015) - First announcement
# 153
# CFP 8th Workshop on  Biomedical and Bioinformatics Challenges for Computer,Science (BBC 2015)
# 167
# Announcement: FMMB 2014
# 193
# 2nd CFP  - Deadline extension - Special issue of BMC Bioinformatics on BioNLP Shared Task 2013
# 199
# ESWC 2014 Final Call for PhD Symposium
# 203
# ESWC 2014 Final Call for Papers
# 234
# CALL FOR PAPERS ACA 2014
# 259
# DILS 2014 Lisbon - 2nd Call for Papers
# 266
# Deadline extension/registration open - Computational Methods for Structural RNAs workshop
# 283
# GIW 2014 2nd CFP
# 291
# ECCB RADIANT workshop: Analysis of Differential Isoform Usage by RNA-seq: Statistical Methodologies and Open Software
# 296
# TPNC 2014: 3rd call for papers
# 309
# IEEE BIBM 2014: Last Call for Papers (dealdine : July 10, 2014)
# 313
# 2nd CFP - MLSB14, the 8th Machine Learning in Systems Biology workshop
# 323
# WCB '14: Last call for papers
# 324
# MLSB 2014: deadline extension and call for posters
# 333
# BRAZILIAN SYMPOSIUM ON BIOINFORMATICS 2014
# 334
# ESCS student symposium, présenter et publier, avant le 30 juin
# 339
# Brazilian Symposium on Bioinformatics 2014
# 364
# SASB 2014 First Call for Papers
# 366
# ESWC 2014 Second Call for Challenge: Semantic Publishing
# 411
# ECCB / JOBIM 2014 : Call for paper OPEN - deadline March 28, 2014 - Strasbourg 7-10 sept 2014
# 423
# AlCoB 2014: extended submission deadline 11 February
# 447
# RegGenSIG 2014 - Call for abstracts
# 448
# CFP DILS 2014-Lisbon, Portugal July 17-18, 2014 (deadline March 2nd)
# 456
# TPNC 2014: 1st call for papers
# 458
# Fwd: European Conference on Computational Biology 2014 : calls and deadlines
# 460
# GCB 2014 Bielefeld
# 461
# CFP - MLSB14, the 8th Machine Learning in Systems Biology workshop
# 462
# FMMB 2014 - second call for papers
# 465
# CFP:  2nd Workshop on Dynamic Networks and Knowledge Discovery (DyNaK, 2014)
# 467
# NETTAB 2014 & Crystal (cl)Year 2014, October 16-17, 2014, Torino, Italy
# 468
# IEEE BIBM 2014 Call for Papers (IEEE International Conference on Bioinformatics and Biomedicine)
# 482
# Fwd: European Conference on Computational Biology 2014 : calls and deadlines
# 515
# DILS2014: Call for Posters and Demos
# 529
# Call for abstracts: Regulatory Genomics Special Interest Group (RegGenSIG)
# 533
# IEEE BIBM 2014 Call for Workshop Proposals (IEEE International Conference on Bioinformatics and Biomedicine)
# 541
# First CFP - Computational Methods for Structural RNAs  - CMSR'14@ECCB'14
# 547
# Call for papers RECOMB-CG 2014
# 552
# ECCB 2014 metagenomics workshop: calls and,deadlines
# 553
# CFP OTM Academy 2014- A Tutored Workshop for PhD Students
# 567
# special issue of TCS-C based on CS2Bio14
# 569
# call for papers special issue of Theoretical Computer Science
# 625
# CALL FOR PAPERS de CPM 2015
# 628
# First EuBIAS and QBI joint meeting in January in Paris
# 632
# CFP MIC'2015 - Save the date
# 662
# Deadline approaching: Lyon SysBio, 19-21 November
# 679
# CFP: 10th Workshop on Constraint-Based Methods for Bioinformatics, Sept 8th 2014, Lyon
# 680
# Call for papers, Nectar track at ECML/PKDD 2014, June 14
# 690
# ESWC 2014 Call for Participation
# 691
# IEEE SSCI Special Session on Optimization Methods in Bioinformatics and Bioengineering
# 695
# Second CfP: IEEE SSCI Special Session on Optimization Methods in Bioinformatics and Bioengineering
# 705
# Call for papers RECOMB-CG 2014
# 728
# ECCB'14 metagenomics workshop: extended deadline
# 737
# CALL FOR ABSTRACTS, Lyon SysBio, 19-21 November 2014
# 742
# Second CFP - Computational Methods for Structural RNAs - CMSR'14
# 750
# BIOMAT 2014 International Symposium
# 770
# SASB, Munich, September 10, 2014 - Call for Participation
# 809
# Call for participation and posters - MLSB14, Machine Learning in Systems Biology
# 846
# CFP: Prague Stringology Conference 2014
# 875
# Fwd: ECCB 2014: 1st call for poster and 2nd call for papers
# 953
# Call for papers: NIPS 2014 workshop on Machine Learning in Computational Biology
# 967
# ISCB-Latin America x-Meeting on Bioinformatics with BSB and SoiBio (Brésil).

# %%
from gensim.models import Word2Vec
from numpy.random import shuffle
import os

sents = [sent for mail in mails for sent in mail.stemSents]

m = Word2Vec(min_count=10, workers = 4)
m.build_vocab(sents)

for i in range(100):
    if i%5 == 0:
        print(i, ' ', end='')

    shuffle(sents)
    m.train(sents)

m.init_sims(replace=True)
# Out:
# 05101520253035404550556065707580859095

# %%
wordSNE = TSNE().fit_transform(m.syn0norm[:1000])

# %%
wordLabels = AffinityPropagation().fit_predict(m.syn0norm[:1000])

# %%
freqs = Counter(w for sent in sents for w in sent)
wordsLogFreqs = np.array([np.log(freqs[w]) for w in m.index2word[:1000]])/np.log(max(freqs.values()))

scatter(wordSNE, m.index2word, wordLabels, wordsLogFreqs)
# Out:
#     <div class="plotdiv" id="fc6640a8-dd0f-45f0-9d03-30851bf43d24"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fc6640a8-dd0f-45f0-9d03-30851bf43d24");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fc6640a8-dd0f-45f0-9d03-30851bf43d24' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a2e25a68-93f1-4f72-a2f6-df161e283a1c": {"title": "Bokeh Application", "roots": {"root_ids": ["1eb164ac-4f03-47af-8a8c-2f7f1d33a5cd", "0bbd130d-21b4-4ca8-a53c-072e9f65bf93", "cd7c9906-d1a3-4ba0-b9e6-de033f847ac3"], "references": [{"id": "a7e47791-4335-4a79-935b-17804d86d1f9", "attributes": {"dimension": 1, "ticker": {"id": "d470e8d5-c6f1-43c2-b37d-f81c4b5ad4dd", "type": "BasicTicker"}, "plot": {"id": "cd7c9906-d1a3-4ba0-b9e6-de033f847ac3", "type": "Plot", "subtype": "Figure"}}, "type": "Grid"}, {"id": "a3a4bacc-f1b7-4f38-a04d-dc363effe4f2", "attributes": {"selection_glyph": null, "nonselection_glyph": {"id": "b7ce47a6-7af1-4f50-9846-8367687690ef", "type": "Circle"}, "hover_glyph": null, "data_source": {"id": "9e60ee89-3de6-48aa-9558-cbab55cd32e8", "type": "ColumnDataSource"}, "glyph": {"id": "502bedd5-eeca-40d7-acd7-8c034266407a", "type": "Circle"}}, "type": "GlyphRenderer"}, {"id": "28f9165c-eefb-4fe8-b24e-8c0888083333", "attributes": {"tooltips": "<p style='font-size: 12px'>@name, @label</p>", "callback": null, "plot": {"id": "0bbd130d-21b4-4ca8-a53c-072e9f65bf93", "type": "Plot", "subtype": "Figure"}}, "type": "HoverTool"}, {"id": "b77645ce-0b74-412b-9d2e-cce1917b878d", "attributes": {"tooltips": "<p style='font-size: 12px'>@name, @label</p>", "callback": null, "plot": {"id": "cd7c9906-d1a3-4ba0-b9e6-de033f847ac3", "type": "Plot", "subtype": "Figure"}}, "type": "HoverTool"}, {"id": "2df1cfe7-8d6f-4e14-a047-6b4a50772c5c", "attributes": {"plot": {"id": "cd7c9906-d1a3-4ba0-b9e6-de033f847ac3", "type": "Plot", "subtype": "Figure"}}, "type": "ResetTool"}, {"id": "b7ce47a6-7af1-4f50-9846-8367687690ef", "attributes": {"fill_alpha": {"value": 0.1}, "radius": {"units": "data", "field": "radius"}, "line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}}, "type": "Circle"}, {"id": "5518c052-8335-469a-9b4f-efe0b5c6fc07", "attributes": {"data": {"color": ["#abdda4", "#fdae61", "#d53e4f", "#fdae61", "#fdae61", "#fee08b", "#fee08b", "#5e4fa2", "#fdae61", "#fee08b", "#ffffbf", "#fdae61", "#abdda4", "#fdae61", "#fdae61", "#fdae61", "#5e4fa2", "#fdae61", "#fdae61", "#fee08b", "#5e4fa2", "#fdae61", "#3288bd", "#abdda4", "#fdae61", "#3288bd", "#d53e4f", "#abdda4", "#fdae61", "#66c2a5", "#abdda4", "#d53e4f", "#abdda4", "#fdae61", "#e6f598", "#9e0142", "#abdda4", "#f46d43", "#ffffbf", "#abdda4", "#3288bd", "#ffffbf", "#ffffbf", "#e6f598", "#5e4fa2", "#5e4fa2", "#5e4fa2", "#f46d43", "#e6f598", "#3288bd", "#abdda4", "#5e4fa2", "#abdda4", "#fee08b", "#abdda4", "#3288bd", "#fee08b", "#e6f598", "#3288bd", "#3288bd", "#fdae61", "#ffffbf", "#66c2a5", "#abdda4", "#e6f598", "#3288bd", "#ffffbf", "#ffffbf", "#66c2a5", "#ffffbf", "#5e4fa2", "#d53e4f", "#d53e4f", "#e6f598", "#66c2a5", "#d53e4f", "#3288bd", "#fdae61", "#3288bd", "#3288bd", "#fdae61", "#5e4fa2", "#ffffbf", "#f46d43", "#fdae61", "#fee08b", "#abdda4", "#abdda4", "#3288bd", "#fdae61", "#5e4fa2", "#f46d43", "#fdae61", "#f46d43", "#e6f598", "#5e4fa2", "#5e4fa2", "#5e4fa2", "#abdda4", "#9e0142", "#d53e4f", "#fdae61", "#9e0142", "#abdda4", "#fee08b", "#f46d43", "#f46d43", "#9e0142", "#abdda4", "#f46d43", "#5e4fa2", "#ffffbf", "#fdae61", "#fdae61", "#abdda4", "#f46d43", "#fee08b", "#fee08b", "#fdae61", "#3288bd", "#e6f598", "#fee08b", "#5e4fa2", "#3288bd", "#fdae61", "#66c2a5", "#9e0142", "#ffffbf", "#3288bd", "#ffffbf", "#fee08b", "#3288bd", "#f46d43", "#9e0142", "#ffffbf", "#5e4fa2", "#9e0142", "#fdae61", "#3288bd", "#fee08b", "#fdae61", "#5e4fa2", "#f46d43", "#f46d43", "#e6f598", "#9e0142", "#5e4fa2", "#9e0142", "#fee08b", "#abdda4", "#9e0142", "#9e0142", "#abdda4", "#5e4fa2", "#fee08b", "#9e0142", "#5e4fa2", "#9e0142", "#fee08b", "#d53e4f", "#abdda4", "#fdae61", "#abdda4", "#fdae61", "#d53e4f", "#66c2a5", "#5e4fa2", "#abdda4", "#d53e4f", "#e6f598", "#3288bd", "#d53e4f", "#ffffbf", "#e6f598", "#abdda4", "#fee08b", "#abdda4", "#fee08b", "#e6f598", "#9e0142", "#e6f598", "#9e0142", "#5e4 ...

# %%
words = np.array(m.index2word)
for l in range(max(wordLabels)):
    lwords = words[wordLabels == l]
    print("cluster#{} (len:{})".format(l, len(lwords)), ' '.join(lwords))
# Out:
# cluster#0 (len:18) de ' et le la un à en du pour dans sur par grand sous dédié atelier actuellement
# cluster#1 (len:12) and of in for with or including between database level provide technical
# cluster#2 (len:5) d l L s aide
# cluster#3 (len:12) data analysis genomic process integration dataset high-throughput control resource quality proteomic visualization
# cluster#4 (len:5) at [ ] fr com
# cluster#5 (len:14) vous votre présent merci faire si intéresser cordialement êtes entrepris inviter nombreux avez chargé
# cluster#6 (len:12) connaissance technique système bon maîtrise anglais pratique général solid ingénierie serait apprentissage
# cluster#7 (len:11) équipe projet développement travail cadre programme objectif context activité appel thématique
# cluster#8 (len:14) au est sont être tout seront ouvert notamment disponible tous adresse ayant particulièrement lié
# cluster#9 (len:17) outil méthode utiliser logiciel solution adapter visualiser permettant nécessaire pipeline nouveau améliorer implémenter existant maintenance produit stratégie
# cluster#10 (len:25) to this that can which other both it how into through been result approach some recent take there if key very no do make able
# cluster#11 (len:6) informatique bio-informatique mathématique appliquer biostatistique universitaire
# cluster#12 (len:9) base traitement intégrer gestion ressource utilisant relationnelle MySQL jeu
# cluster#13 (len:9) biology computational system evolutionary modelling European metabolic advance synthetic
# cluster#14 (len:9) que ainsi qu comme certain chez exemple même effet
# cluster#15 (len:13) model method us tool approaches problem statistical novel mathematical optimization concept task search
# cluster#16 (len:7) nous bien année offre avons cela recherchons
# cluster#17 (len:16) paper submission abstract publication contribution invited accept author version speak extend review submitted full final All
# cluster#18 (len:5) web site technologie via semantic
# cluster#19 (len:4) cancer diagnostic patient term
# cluster#20 (len:16) workshop cours conference session program follow school tutorial main ECCB meet goal organizer symposium day organized
# cluster#21 (len:6) poste stage thèse sujet cet DE
# cluster#22 (len:7) not but include any read limited only
# cluster#23 (len:9) algorithm graph expertise algorithmic image plan code automatic ontology
# cluster#24 (len:10) structure protein interaction structural RNA functional function target prediction small
# cluster#25 (len:4) " » « omics
# cluster#26 (len:19) project new develop development we our aim use design software engineer understand lead experimental exist methodology help dedicated advanced
# cluster#27 (len:17) network gene expression evolution set identify regulation event pathway drug discovery individual transcription change species mechanism detection
# cluster#28 (len:7) biologie génomique génétique moléculaire fonctionnelle clinic humain
# cluster#29 (len:14) their present post select each oral original demo short number call track industrial discuss
# cluster#30 (len:21) . A S M J & D al etc F P T G H B I N V E U O
# cluster#31 (len:8) centre national calcul infrastructure center français IFB contre
# cluster#32 (len:6) place mis participer mettre point conception
# cluster#33 (len:5) mission description aura principal tâche
# cluster#34 (len:9) NGS sequencing high rna-seq ? DNA generation next genome-wide
# cluster#35 (len:15) experience knowledge skill programming strong communication good language background english excellent required ability basic practical
# cluster#36 (len:15) a be will also participant It they would expect opportunity involved role consider require register
# cluster#37 (len:16) is available open registration time french website now located link funded job An access essential until
# cluster#38 (len:8) recherche plateforme communauté technologique créer plate-forme autour construction
# cluster#39 (len:4) CV motivation lettre letter
# cluster#40 (len:8) inform more about detail further see found than
# cluster#41 (len:10) research work group team laboratory environment lab platform host head
# cluster#42 (len:15) these important different most several relevant best many order various them allow selection find response
# cluster#43 (len:12) genome sequence large multiple regulatory motif reconstruction assembly classification sample metagenomic perform
# cluster#44 (len:10) gène cellule protéine non identifier espèce condition nombre spécifique virus
# cluster#45 (len:7) mois partir durée contrat CDD début moins
# cluster#46 (len:9) cette autre deux plusieurs référence différentes dont chaque rôle
# cluster#47 (len:10) the one two reference three up name academic least source
# cluster#48 (len:4) Le propos Ce Un
# cluster#49 (len:6) institut curie inserm pierre cea pasteur
# cluster#50 (len:15) ce développer réaliser interface été ensemble ont résultat déjà valider suivi effectuer rapport sa étape
# cluster#51 (len:8) ( - cnrs université UMR Lyon rue Equipe
# cluster#52 (len:11) interest you please your apply To send cover submit forward colleague
# cluster#53 (len:10) donner génome annoter séquence transcriptome détection ARN comparaison prédiction assemblage
# cluster#54 (len:10) qui Il elle il également mais aussi jour donc y
# cluster#55 (len:14) / C R langage programmer python java perl ... script objet SQL javascript php
# cluster#56 (len:6) scientific service support management expert futur
# cluster#57 (len:5) _email_ contact email address e-mail
# cluster#58 (len:9) étude nouvelle modèle approche particulier basé sélection expérimental problème
# cluster#59 (len:5) dynamic complex simuler test représenter
# cluster#60 (len:13) , university UK USA Germany technology state Spain Italy David College city Canada
# cluster#61 (len:7) candidature inscription envoyer limite demand soumission dossier
# cluster#62 (len:3) Dr prof professor
# cluster#63 (len:9) field all topic area related challenge ca general subject
# cluster#64 (len:17) : _year_ date deadline may Jun september notification July March acceptance early due October April August January
# cluster#65 (len:6) plus ne pas n me car
# cluster#66 (len:10) candidat application should applicant must successful degree qualification Ph hold
# cluster#67 (len:8) student scientist biologist bioinformatician who bring together build
# cluster#68 (len:7) as such possible well rang global Eric
# cluster#69 (len:6) on based focus particular major current
# cluster#70 (len:5) environnement linux exploit unix administrer
# cluster#71 (len:6) analyse transcriptomic comparative protéomique quantitative mass
# cluster#72 (len:11) molecular genetic study cell disease human processes specific cellular chemical epigenetic
# cluster#73 (len:5) part question aspect organism consist
# cluster#74 (len:6) La sera personne devra recruter stagiaire
# cluster#75 (len:7) position PhD postdoctoral postdoc fellow post-doctoral post-doc
# cluster#76 (len:13) son notre utilisateur chercheur bioinformaticien biologistes étudiant besoin partenaire client informaticien culture collègue
# cluster#77 (len:7) ; learn machine min big biomedical text
# cluster#78 (len:6) ) e g i nature Univ
# cluster#79 (len:7) séquençage haut débit associé générer ADN haut-débit
# cluster#80 (len:7) _number_ _symbol_ _url_ tel cedex www fax
# cluster#81 (len:8) page format pdf document standard accord article word
# cluster#82 (len:12) by have from In train its within community during member package where
# cluster#83 (len:6) form Paris Ecole école normal supérieur
# cluster#84 (len:10) public life medicine clinical health department social activity medical break
# cluster#85 (len:5) list mail Dear message Bonjour
# cluster#86 (len:7) year start euros month salary before previous
# cluster#87 (len:4) Dan temps premier second
# cluster#88 (len:9) bioinformatic science statistic computer Comput applied mathematics biostatistics theoretical
# cluster#89 (len:9) afin assurer évolution évaluer analyser permet comprendre étudier explorer
# cluster#90 (len:5) unit identification impact action unique
# cluster#91 (len:5) fonction charge pris conférence compte
# cluster#92 (len:6) avec collaborer entre relation lien ligne
# cluster#93 (len:11) international issue special journal publish first chair lecture proceedings spring On
# cluster#94 (len:10) lieu _hour_ novembre comité avant mai fin septembre avril octobre
# cluster#95 (len:7) ou ingénieur profil niveau master bac diplôme
# cluster#96 (len:8) domain très suivant intérêt avoir fort complet savoir
# cluster#97 (len:8) laboratoire sein responsable enseignement Au département directeur membre
# cluster#98 (len:5) cloud cluster framework computing performance
# cluster#99 (len:14) leur réseau biologique modéliser différents maladie santé cellulaire impliquer réguler métabolique mécanisme processus caractériser
# cluster#100 (len:7) type Galaxy architecture workflow production module capable
# cluster#101 (len:8) se En société parti depuis première fait pay
# cluster#102 (len:11) population plant variant association signal animal mutation variation long divers distribution
# cluster#103 (len:12) France inra Montpellier inria campus Grenoble Strasbourg Bordeaux toulouse Evry FR Rennes
# cluster#104 (len:8) expérience De compétence requis selon rechercher souhaité rémunération
# cluster#105 (len:10) organiser qualité capacité travailler sens autonomie rigueur esprit écrit relationnel
